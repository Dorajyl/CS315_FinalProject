# %%
import pandas as pd
import numpy as np
import csv, json
import matplotlib.pyplot as plt
import re
from urllib.parse import urlparse
from pandas import Series

# %%
def getID(url):
    parsed_url = urlparse(url)
    path_segments = parsed_url.path.split('/')
    return int(path_segments[3])
getID("https://www.tiktokv.com/share/video/7315561816673750318/")
# Out:
# 7315561816673750318

# %%
def processCsv(csvd):
    csvdf = csvd
    position = csvdf.columns.get_loc('video_timestamp') + 1
    csvdf.insert(position, 'video_time_watched', np.nan)
    return csvdf

# %%
def processJson(jsond): #for Sec2Gr2 files
    jsondf = jsond
    jsondf['video_id'] = jsondf['Link'].apply(getID)
    return jsondf

def processJson2(jsonfilename): #for Sec1Gr1 files
    filename = f'{jsonfilename}'
    with open(filename, 'r') as file:
        jsondata = json.load(file)

    jsondict = {'Date':[],'Link':[],'video_id':[]}
    for video in jsondata['data']:
        jsondict['Link'].append(video[1])
        jsondict['video_id'].append(getID(video[1])) 
        jsondict['Date'].append(video[0])

    jsondf = pd.DataFrame(jsondict)
    return jsondf

# %%
#for ech pair create new df with date
def merged_date(csvd, jsond):
    csvdf = csvd
    jsondf = jsond
    csvrow = 0
    jsonrow = 0
    for id in jsondf['video_id']: #for each video watched in json
        if id == csvdf['video_id'][csvrow]: #if the id for the json equals the next csv row
            csvdf.loc[csvrow, 'video_time_watched'] = jsondf.loc[jsonrow, 'Date']
            if csvrow < len(csvdf)-1:
                csvrow = csvrow+1   #go on to the next csv row
        jsonrow = jsonrow + 1  #go to the next json no matter if match or not
    return csvdf

# %%
#processjson and csv and insert
def mergefile(csv,json): #for Sec2gr2 files
    csvfile = pd.read_csv(f'{csv}')
    jsonfile = pd.read_json(f'{json}')
    return merged_date(processCsv(csvfile), processJson(jsonfile))

def mergefile2(csv,json): #for Sec1Gr1 files
    csvfile = pd.read_csv(f'{csv}')
    jsonfile = processJson2(f'{json}')
    return merged_date(processCsv(csvfile),jsonfile)
    
#sec1gr2_csv = pd.read_csv('pyktok_data/Sec1Gr2_26301.csv') #come back label wrong
#sec1gr2_json = pd.read_json('user_jsons/Sec2Gr2_26301.json')

# %%
csvsize10824 = len(pd.read_csv('pyktok_data/Sec1Gr1_10824.csv'))
with open('user_jsons/Sec1Gr1_10824.json', 'r') as file:
    jsonfile10824 = json.load(file)
jsonsize10824 = len(jsonfile10824['data'])


csvsize12345 = len(pd.read_csv('pyktok_data/Sec1Gr1_12345.csv'))
with open('user_jsons/Sec1Gr1_12345.json', 'r') as file:
    jsonfile12345 = json.load(file)
jsonsize12345 = len(jsonfile12345['data'])

csvsize50405 = len(pd.read_csv('pyktok_data/Sec1Gr1_50405.csv'))
with open('user_jsons/Sec1Gr1_50405.json', 'r') as file:
    jsonfile50405 = json.load(file)
jsonsize50405 = len(jsonfile50405['data'])

csvsize26301 = len(pd.read_csv('pyktok_data/Sec1Gr2_26301.csv'))
jsonsize26301 = len(pd.read_json('user_jsons/Sec2Gr2_26301.json'))


csvsize33534 = len(pd.read_csv('pyktok_data/Sec1Gr2_33534.csv'))
jsonsize33534 = len(pd.read_json('user_jsons/Sec2Gr2_33534.json'))

csvsize38129 = len(pd.read_csv('pyktok_data/Sec1Gr2_38129.csv'))
jsonsize38129 = len(pd.read_json('user_jsons/Sec2Gr2_38129.json'))


csvsize11111 = len(pd.read_csv('pyktok_data/Sec1Gr3_11111.csv'))
jsonsize11111 = len(pd.read_json('user_jsons/Sec1Gr3_11111.json'))


sizes = [('CSV Size','Json size'),(csvsize10824, jsonsize10824), 
      (csvsize12345, jsonsize12345),
      (csvsize50405,jsonsize50405),
      (csvsize26301,jsonsize26301),
      (csvsize33534, jsonsize33534),
      (csvsize38129, jsonsize38129),
      (csvsize11111, jsonsize11111)]

sizes
# Out:
# /var/folders/ls/b1_wv00s5r5fjstz103_p3rh0000gn/T/ipykernel_31834/3874688336.py:28: DtypeWarning: Columns (8,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   csvsize11111 = len(pd.read_csv('pyktok_data/Sec1Gr3_11111.csv'))
# [('CSV Size', 'Json size'),
#  (10999, 26267),
#  (19102, 20621),
#  (24288, 26117),
#  (8068, 82371),
#  (7663, 40254),
#  (31, 32),
#  (58836, 27936)]

# %%
df26301 = mergefile('pyktok_data/Sec1Gr2_26301.csv','user_jsons/Sec2Gr2_26301.json')
df33534 = mergefile('pyktok_data/Sec1Gr2_33534.csv','user_jsons/Sec2Gr2_33534.json')
df38129 = mergefile('pyktok_data/Sec1Gr2_38129.csv', 'user_jsons/Sec2Gr2_38129.json')
df11111 = mergefile('pyktok_data/Sec1Gr3_11111.csv','user_jsons/Sec1Gr3_11111.json')
df10824 = mergefile2('pyktok_data/Sec1Gr1_10824.csv','user_jsons/Sec1Gr1_10824.json')
df12345 = mergefile2('pyktok_data/Sec1Gr1_12345.csv','user_jsons/Sec1Gr1_12345.json')
df50405 = mergefile2('pyktok_data/Sec1Gr1_50405.csv','user_jsons/Sec1Gr1_50405.json')

dfs = [df26301,df33534,df38129,df10824,df12345,df50405,df11111]

all_dfs = pd.concat(dfs)

df33534.shape
# Out:
# /var/folders/ls/b1_wv00s5r5fjstz103_p3rh0000gn/T/ipykernel_31834/966991795.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2024-03-06 19:44:41' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   csvdf.loc[csvrow, 'video_time_watched'] = jsondf.loc[jsonrow, 'Date']
# /var/folders/ls/b1_wv00s5r5fjstz103_p3rh0000gn/T/ipykernel_31834/966991795.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2024-03-08 03:42:17' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   csvdf.loc[csvrow, 'video_time_watched'] = jsondf.loc[jsonrow, 'Date']
# /var/folders/ls/b1_wv00s5r5fjstz103_p3rh0000gn/T/ipykernel_31834/2354271149.py:3: DtypeWarning: Columns (8,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   csvfile = pd.read_csv(f'{csv}')
# /var/folders/ls/b1_wv00s5r5fjstz103_p3rh0000gn/T/ipykernel_31834/966991795.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2024-02-09 23:35:22' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   csvdf.loc[csvrow, 'video_time_watched'] = jsondf.loc[jsonrow, 'Date']
# /var/folders/ls/b1_wv00s5r5fjstz103_p3rh0000gn/T/ipykernel_31834/966991795.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2024-02-26 02:58:45' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   csvdf.loc[csvrow, 'video_time_watched'] = jsondf.loc[jsonrow, 'Date']
# /var/folders/ls/b1_wv00s5r5fjstz103_p3rh0000gn/T/ipykernel_31834/966991795.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2023-11-18 01:26:28' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   csvdf.loc[csvrow, 'video_time_watched'] = jsondf.loc[jsonrow, 'Date']
# (7663, 21)

# %%
ads10824 = df10824[df10824['video_is_ad']==True]
ads11111 = df11111[df11111['video_is_ad']==True]
ads50405 = df50405[df50405['video_is_ad']==True]
ads12345 = df12345[df12345['video_is_ad']==True]
ads26301 = df26301[df26301['video_is_ad']==True]
ads38129 = df38129[df38129['video_is_ad']==True]
ads33534 = df33534[df33534['video_is_ad']==True]

allads = [ads10824,ads11111,ads50405,ads12345,ads26301,ads38129,ads33534]

for df in allads:
    print(df.size)

allads = [ads10824,ads50405,ads12345,ads26301,ads38129,ads33534]
# Out:
# 5984
# 0
# 74466
# 37296
# 22659
# 42
# 26355
#                  video_id      video_timestamp  video_time_watched  \
# 24    7327757398427438378  2024-01-24T15:02:00                 NaN
# 30    7314122026002795777  2023-12-18T21:09:04                 NaN
# 36    7273551672897457451  2023-08-31T14:15:27                 NaN
# 42    7337826415993163009  2024-02-20T18:14:11                 NaN
# 47    7335575308197760257  2024-02-14T16:38:43                 NaN
# ...                   ...                  ...                 ...
# 7633  7319577304152296750  2024-01-02T13:58:42                 NaN
# 7640  7314770555217906946  2023-12-20T15:05:40                 NaN
# 7646  7318767572969590058  2023-12-31T09:36:36                 NaN
# 7652  7262027736665836846  2023-07-31T12:56:44                 NaN
# 7659  7267607669609860354  2023-08-15T13:49:35                 NaN
#
#       video_duration video_locationcreated  \
# 24               6.0                    US
# 30              17.0               FAKE-AD
# 36              13.0                    US
# 42              14.0               FAKE-AD
# 47              12.0               FAKE-AD
# ...              ...                   ...
# 7633            27.0                    US
# 7640             6.0               FAKE-AD
# 7646            26.0                    US
# 7652            38.0                    US
# 7659            17.0                   NaN
#
#                                         suggested_words  video_diggcount  \
# 24    skittles littles, skittles, Skittles Candy, mi...           7385.0
# 30    savings, Saving Money Envelopes, saving money ...           2595.0
# 36    pizza rice, pizza rice recipe, seeds of change...          96600.0
# 42    Opi Nail Polish, Painting My Nails, Makeup Pal...          57800.0
# 47    knorr, Good Food, Food To Eat, food ideas, foo...           1715.0
# ...                                                 ...              ...
# 7633                                                NaN          16900.0
# 7640                                                NaN           6282.0
# 7646                                                NaN          79400.0
# 7652  jon seaton highlights, jon seaton, Day In Life...         710700.0
# 7659  Disney 100, Cricut Joy, Disney, cricut, Amazon...         155000.0
#
#       video_sharecount  video_commentcount  video_playcount  ... video_is_ad  \
# 24               131.0               257.0       21800000.0  ...        True
# 30                 5.0                 1.0       19200000.0  ...        True
# 36              2218.0              1154.0       43300000.0  ...        True
# 42                 4.0               204.0       13900000.0  ...        True
# 47                30.0                17.0       15200000.0  ...        True
# ...                ...                 ...              ...  ...         ...
# 7633             143.0               305.0       49800000.0  ...        True
# 7640              43.0                 0.0       17500000.0  ...        True
# 7646             445.0               584.0       18300000.0  ...        True
# 7652            2654.0              2120.0      136400000.0  ...        True
# 7659            3921.0                 0.0      338900000.0  ...        True
#
#       video_stickers        author_username            author_name  \
# 24               NaN               skittles               skittles
# 30               NaN  Fidelity Smart Money℠  Fidelity Smart Money℠
# 36               NaN  seedsofchangeofficial        Seeds Of Change
# 42               NaN                    OPI                    OPI
# 47               NaN                  Knorr                  Knorr
# ...              ...                    ...                    ...
# 7633             NaN                teatinz                 Tivona
# 7640             NaN                 Keurig                 Keurig
# 7646             NaN                   espn                   ESPN
# 7652             NaN              jonseaton             Jon Seaton
# 7659             NaN        Amazon Shopping        Amazon Shopping
#
#      author_followercount  author_followingcount  author_heartcount  \
# 24                    NaN                    NaN                NaN
# 30                    NaN                    NaN                NaN
# 36                    NaN                    NaN                NaN
# 42                    NaN                    NaN                NaN
# 47                    NaN                    NaN                NaN
# ...                   ...                    ...                ...
# 7633                  NaN                    NaN                NaN
# 7640                  NaN                    NaN                NaN
# 7646                  NaN                    NaN                NaN
# 7652                  NaN                    NaN                NaN
# 7659                  NaN                    NaN                NaN
#
#       author_videocount  author_diggcount  author_verified
# 24                  NaN               NaN             True
# 30                  NaN               NaN            False
# 36                  NaN               NaN             True
# 42                  NaN               NaN            False
# 47                  NaN               NaN            False
# ...                 ...               ...              ...
# 7633                NaN               NaN            False
# 7640                NaN               NaN            False
# 7646                NaN               NaN             True
# 7652                NaN               NaN            False
# 7659                NaN               NaN            False
#
# [1255 rows x 21 columns]

# %%
#Testing if the video_time_watched has values instead of NaN
#ads26301['video_time_watched'] = pd.to_datetime(ads26301['video_time_watched'])
#print(ads26301.groupby(ads26301['video_time_watched'].dt.to_period('M')).size())
# Out:
# video_time_watched
# 2024-02    445
# 2024-03    634
# Freq: M, dtype: int64

# %%
someads = [ads50405,ads12345,ads26301] #three users that have values for video_time_watched

fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 10))

adsIDs = ['50405','12345','26301']

for i, adsdf in enumerate(someads):
    adsdf['video_time_watched'] = pd.to_datetime(adsdf['video_time_watched'])
    monthlycounts = adsdf.groupby(adsdf['video_time_watched'].dt.to_period('M')).size()
    
    ax = axes[i]
    monthlycounts.plot(kind='line', marker='o', linestyle='-',ax=ax)
    
    ax.set_title('User '+ adsIDs[i])
    ax.set_xlabel('Month')
    ax.set_ylabel('Number of Ads')
    ax.grid(True)
# Out:
# /var/folders/ls/b1_wv00s5r5fjstz103_p3rh0000gn/T/ipykernel_31834/936717653.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adsdf['video_time_watched'] = pd.to_datetime(adsdf['video_time_watched'])
# /var/folders/ls/b1_wv00s5r5fjstz103_p3rh0000gn/T/ipykernel_31834/936717653.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adsdf['video_time_watched'] = pd.to_datetime(adsdf['video_time_watched'])
# /var/folders/ls/b1_wv00s5r5fjstz103_p3rh0000gn/T/ipykernel_31834/936717653.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adsdf['video_time_watched'] = pd.to_datetime(adsdf['video_time_watched'])

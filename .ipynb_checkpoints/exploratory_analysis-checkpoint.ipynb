# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import re
import os
from collections import Counter

# %% [markdown]
# ## Read in Data

# %%
os.listdir('pyktok_data')
# Out:
# ['results_50405_full.csv',
#  'Sec2Gr3_77777.csv',
#  'Sec2Gr3_77217.csv',
#  'Sec2Gr3_74721.csv',
#  'results_38129.csv',
#  'results_26301.csv',
#  'results_33534.csv',
#  'results_12345_full.csv',
#  'results_10824_full.csv']

# %%
filenames = """['results_50405_full.csv',
 'Sec2Gr3_77777.csv',
 'Sec2Gr3_77217.csv',
 'Sec2Gr3_74721.csv',
 'results_38129.csv',
 'results_26301.csv',
 'results_33534.csv',
 'results_12345_full.csv',
 'results_10824_full.csv']"""

pattern = re.compile('\d\d\d\d\d')
codes = pattern.findall(filenames)
for code in codes: print(f"'{code}',")
# Out:
# '50405',
# '77777',
# '77217',
# '74721',
# '38129',
# '26301',
# '33534',
# '12345',
# '10824',

# %%
codes = ['50405','77777','77217','74721','38129','26301','33534','12345','10824']

# %%
df50405 = pd.read_csv('pyktok_data/results_50405_full.csv')
df77777 = pd.read_csv('pyktok_data/Sec2Gr3_77777.csv')
df77217 = pd.read_csv('pyktok_data/Sec2Gr3_77217.csv')
df74721 = pd.read_csv('pyktok_data/Sec2Gr3_74721.csv')
df38129 = pd.read_csv('pyktok_data/results_38129.csv')
df26301 = pd.read_csv('pyktok_data/results_26301.csv')
df33534 = pd.read_csv('pyktok_data/results_33534.csv')
df12345 = pd.read_csv('pyktok_data/results_12345_full.csv')
df10824 = pd.read_csv('pyktok_data/results_10824_full.csv')

# %%
dfs = [df50405,df77777,df77217,df38129,df26301,df33534,df12345,df10824]

# %%
for code, df in zip(codes, dfs):
    print(f"User {code}, {len(df)}  videos")
# Out:
# User 50405, 24288  videos
# User 77777, 482  videos
# User 77217, 15424  videos
# User 74721, 31  videos
# User 38129, 8068  videos
# User 26301, 7663  videos
# User 33534, 19102  videos
# User 12345, 10999  videos

# %%
# add a 'user' column to each df
for code, df in zip(codes, dfs): 
    df['user'] = code

all_dfs = pd.concat(dfs)
all_dfs.head()
# Out:
#               video_id      video_timestamp  video_duration  \
# 0  7302601347327905070  2023-11-17T20:03:14            66.0
# 1  7326753111513632043  2024-01-21T22:04:30            13.0
# 2  7325244024623746346  2024-01-17T20:28:27            11.0
# 3  7330343097244618026  2024-01-31T14:15:49            85.0
# 4  7329927237359193386  2024-01-30T11:21:56            69.0
#
#   video_locationcreated                                    suggested_words  \
# 0                    US                                                NaN
# 1                    US  yeslydimate, yesly and tony, I Look Like A Pen...
# 2                    US  yeslydimate, tony and yesly, Yesly, yesly sure...
# 3                    US                                                NaN
# 4                    US  jenna marbles, Neon Genesis Evangelion, doorkn...
#
#    video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 0          19400.0              40.0                86.0         147000.0
# 1         395800.0             525.0               259.0        3300000.0
# 2         828300.0            2128.0               750.0        7100000.0
# 3          56000.0            8358.0              1994.0        1500000.0
# 4         199900.0            2854.0              1352.0        1200000.0
#
#                                    video_description  ...  author_username  \
# 0  Talk about a humbling experience. Got a dress ...  ...  divineontheroad
# 1                  we’ve reached full mini bob stage  ...      yeslydimate
# 2                                                NaN  ...      yeslydimate
# 3  #stitch with @Casey Smith If it works for you,...  ...     _sydneymoran
# 4                                       Opportunity   ...          mburkez
#
#         author_name author_followercount author_followingcount  \
# 0  Sydney Ferbrache                  NaN                   NaN
# 1       yeslydimate                  NaN                   NaN
# 2       yeslydimate                  NaN                   NaN
# 3      _sydneymoran                  NaN                   NaN
# 4     Doorknob Girl                  NaN                   NaN
#
#    author_heartcount  author_videocount  author_diggcount  author_verified  \
# 0                NaN                NaN               NaN            False
# 1                NaN                NaN               NaN            False
# 2                NaN                NaN               NaN            False
# 3                NaN                NaN               NaN            False
# 4                NaN                NaN               NaN            False
#
#     user  Unnamed: 0
# 0  50405         NaN
# 1  50405         NaN
# 2  50405         NaN
# 3  50405         NaN
# 4  50405         NaN
#
# [5 rows x 22 columns]

# %%
ads50405 = df50405[df50405['video_is_ad']==True]
ads77777 = df77777[df77777['video_is_ad']==True]
ads77217 = df77217[df77217['video_is_ad']==True]
ads74721 = df74721[df74721['video_is_ad']==True]
ads38129 = df38129[df38129['video_is_ad']==True]
ads26301 = df26301[df26301['video_is_ad']==True]
ads33534 = df33534[df33534['video_is_ad']==True]
ads12345 = df12345[df12345['video_is_ad']==True]
ads10824 = df10824[df10824['video_is_ad']==True]

# %%
ads = [ads50405,ads77777,ads77217,ads38129,ads26301,ads33534,ads12345,ads10824]

# %%
all_ads = pd.concat(ads)
# Alternatively
# all_ads = all_dfs[all_dfs['video_is_ad']==True]

# %%
all_ads
# Out:
#                   video_id      video_timestamp  video_duration  \
# 121    7307688151638641950  2023-12-01T13:02:38            62.0
# 342    7324830221964807426  2024-01-16T17:42:19            10.0
# 350    7322947907064253698  2024-01-11T15:57:58            15.0
# 361    7322912557356911874  2024-01-11T13:40:49            37.0
# 367    7323282996813991210  2024-01-12T13:38:34            29.0
# ...                    ...                  ...             ...
# 10967  7310226877233270017  2023-12-08T09:13:53            22.0
# 10973  7302548495989345538  2023-11-17T16:37:50             6.0
# 10980  7302185270420557086  2023-11-16T17:08:29            41.0
# 10992  7301687488719064363  2023-11-15T08:56:51            36.0
# 10998  7303725600458542379  2023-11-20T20:45:45            28.0
#
#       video_locationcreated  \
# 121                      US
# 342                 FAKE-AD
# 350                 FAKE-AD
# 361                 FAKE-AD
# 367                      US
# ...                     ...
# 10967               FAKE-AD
# 10973                   NaN
# 10980                    US
# 10992                    US
# 10998                    US
#
#                                          suggested_words  video_diggcount  \
# 121    books, book tok, barnes & noble, barnes and no...         238300.0
# 342                                                  NaN            991.0
# 350                                                  NaN          44700.0
# 361                                                  NaN          73700.0
# 367                                                  NaN           2257.0
# ...                                                  ...              ...
# 10967                                                NaN           3649.0
# 10973                                                NaN           4473.0
# 10980  Clearstem Acne Supplement, Clearstem, skincare...            500.0
# 10992                                                NaN          14700.0
# 10998                                                NaN           8543.0
#
#        video_sharecount  video_commentcount  video_playcount  \
# 121               187.0              1670.0        1800000.0
# 342                 9.0                10.0         422500.0
# 350              1999.0               484.0        2100000.0
# 361                 8.0                 0.0        8400000.0
# 367                21.0                21.0          96000.0
# ...                 ...                 ...              ...
# 10967              69.0                 0.0       11400000.0
# 10973             101.0               184.0       30600000.0
# 10980              22.0                17.0         900100.0
# 10992             224.0                37.0       19900000.0
# 10998              42.0                87.0       11800000.0
#
#                                        video_description  ...  \
# 121                                                  lol  ...
# 342    The perfect gift for your Valentine (and your ...  ...
# 350    The new Gothic Americana collection is here. W...  ...
# 361    The bugs are back in town! A Real Bug's Life i...  ...
# 367    Full outfit is @abercrombie YPB active 👟♥️ #ab...  ...
# ...                                                  ...  ...
# 10967       New top deals to score, now through Saturday  ...
# 10973  Simplicity that’s bound to satisfy. Snack diff...  ...
# 10980  The Easiest Way to Ditch Acne #clearstemskinca...  ...
# 10992  #ad My skincare secret: @Olay Skin Care Vitami...  ...
# 10998  #ad for a comfier period, always look for cott...  ...
#
#          author_username             author_name author_followercount  \
# 121       goddamnitannie          annie kartalia                  NaN
# 342          coachoutlet             coachoutlet                  NaN
# 350          Dr. Martens             Dr. Martens                  NaN
# 361           natgeowild              natgeowild                  NaN
# 367           simmykinns             simmykinns🍒                  NaN
# ...                  ...                     ...                  ...
# 10967             Target                  Target                  NaN
# 10973         PopCorners              PopCorners                  NaN
# 10980  clearstemskincare      CLEARSTEM Skincare                  NaN
# 10992       tabitha.blue             TabithaBlue                  NaN
# 10998     callmedoctor.p  Dr. Kerry-Anne Perkins                  NaN
#
#       author_followingcount  author_heartcount  author_videocount  \
# 121                     NaN                NaN                NaN
# 342                     NaN                NaN                NaN
# 350                     NaN                NaN                NaN
# 361                     NaN                NaN                NaN
# 367                     NaN                NaN                NaN
# ...                     ...                ...                ...
# 10967                   NaN                NaN                NaN
# 10973                   NaN                NaN                NaN
# 10980                   NaN                NaN                NaN
# 10992                   NaN                NaN                NaN
# 10998                   NaN                NaN                NaN
#
#        author_diggcount  author_verified   user  Unnamed: 0
# 121                 NaN            False  50405         NaN
# 342                 NaN            False  50405         NaN
# 350                 NaN            False  50405         NaN
# 361                 NaN            False  50405         NaN
# 367                 NaN            False  50405         NaN
# ...                 ...              ...    ...         ...
# 10967               NaN            False  12345     10507.0
# 10973               NaN            False  12345     10513.0
# 10980               NaN             True  12345     10520.0
# 10992               NaN            False  12345     10532.0
# 10998               NaN            False  12345     10538.0
#
# [10015 rows x 22 columns]

# %%
for code, df, adDf in zip(codes, dfs, ads):
    print(f'{code}')
    print(f'Total number of videos: {df.shape[0]}')
    print(f'Number of ads: {adDf.shape[0]}')
    print(f'Percentage of all videos in browsing history: {round(adDf.shape[0]/df.shape[0],3)}')
    print()
# Out:
# 50405
# Total number of videos: 24288
# Number of ads: 3546
# Percentage of all videos in browsing history: 0.146
#
# 77777
# Total number of videos: 482
# Number of ads: 85
# Percentage of all videos in browsing history: 0.176
#
# 77217
# Total number of videos: 15424
# Number of ads: 2000
# Percentage of all videos in browsing history: 0.13
#
# 74721
# Total number of videos: 31
# Number of ads: 2
# Percentage of all videos in browsing history: 0.065
#
# 38129
# Total number of videos: 8068
# Number of ads: 1079
# Percentage of all videos in browsing history: 0.134
#
# 26301
# Total number of videos: 7663
# Number of ads: 1255
# Percentage of all videos in browsing history: 0.164
#
# 33534
# Total number of videos: 19102
# Number of ads: 1776
# Percentage of all videos in browsing history: 0.093
#
# 12345
# Total number of videos: 10999
# Number of ads: 272
# Percentage of all videos in browsing history: 0.025

# %% [markdown]
# ### Find all the advertisers

# %%
for i in range(8):
    print(f'{codes[i]}')
    print(f"Number of advertiser accounts: {len(ads[i]['author_name'])}")
    print(f"Number of unique advertiser accounts: {len(ads[i]['author_name'].unique())}")
    print()
# Out:
# 50405
# Number of advertiser accounts: 3546
# Number of unique advertiser accounts: 1704
#
# 77777
# Number of advertiser accounts: 85
# Number of unique advertiser accounts: 71
#
# 77217
# Number of advertiser accounts: 2000
# Number of unique advertiser accounts: 655
#
# 74721
# Number of advertiser accounts: 2
# Number of unique advertiser accounts: 2
#
# 38129
# Number of advertiser accounts: 1079
# Number of unique advertiser accounts: 534
#
# 26301
# Number of advertiser accounts: 1255
# Number of unique advertiser accounts: 666
#
# 33534
# Number of advertiser accounts: 1776
# Number of unique advertiser accounts: 632
#
# 12345
# Number of advertiser accounts: 272
# Number of unique advertiser accounts: 238

# %%
for i in range(8):
    print(f'{codes[i]}')
    print(ads[i]['author_name'].value_counts().head(10))
    print()
# Out:
# 50405
# author_name
# TikTok             27
# theouai            26
# firstaidbeauty     26
# tacobell           24
# Crumbl Cookies     23
# Favor Delivery     20
# H-E-B              18
# TikTok Research    17
# Allstate           17
# marshalls          16
# Name: count, dtype: int64
#
# 77777
# author_name
# Shop with Google    4
# sephora             4
# Ray-Ban Meta        2
# official_nct        2
# Amazon Home         2
# Burt's Bees         2
# 🦋Lauren Kawano🦋     2
# Fancy Feast         2
# Steffie Price 🎀     2
# OREO Cookie         2
# Name: count, dtype: int64
#
# 77217
# author_name
# Amazon Shopping         137
# Amazon                   75
# Amazon Home              47
# Sephora                  37
# Shop with Google         34
# nyxcosmetics             28
# rabanne                  22
# Amazon Fashion           19
# lorealparisusa           19
# therealsourpatchkids     18
# Name: count, dtype: int64
#
# 74721
# author_name
# Decsteamboy us    1
# Alexis Johnson    1
# Name: count, dtype: int64
#
# 38129
# author_name
# Chewy              32
# Amazon             19
# NIRVANA JEWELRY    18
# Dove               18
# MONOPOLY GO!       14
# tjmaxx             13
# Amazon Shopping    11
# Peacock            11
# A24                10
# OPI                10
# Name: count, dtype: int64
#
# 26301
# author_name
# Amazon Shopping        21
# Walmart                20
# REESE'S                15
# Starbucks              14
# Maybelline New York    13
# McDonalds              12
# McDonald's             12
# Dove                   10
# YSLBEAUTY              10
# marshalls              10
# Name: count, dtype: int64
#
# 33534
# author_name
# DoorDash - Food Delivery          145
# Hinge - Dating & Relationships     65
# Tinder Dating app. Meet People     38
# Searchlight Pictures               27
# Grubhub                            19
# Canva: Design, Photo & Video       19
# McDonald's                         18
# Nordstrom                          17
# FordMotorCompany                   17
# Max                                17
# Name: count, dtype: int64
#
# 12345
# author_name
# PSYCHIC FEVER               4
# Godwin                      3
# JOSH LEVI                   3
# EKANE 💅🏽                    2
# Scrubbing Bubbles           2
# givenchybeauty              2
# CapitalOne                  2
# Ray-Ban Meta                2
# Introducing Meta Quest 3    2
# Tidy Cats                   2
# Name: count, dtype: int64

# %%
def plot_value_counts(code,df):
    val_counts = df['author_name'].value_counts()
    plt.style.use('ggplot')
    plt.figure(figsize=(5,3))
    sns.histplot(val_counts,bins=20)
    plt.title(f'Distribution of Advertiser Value Counts for User {code}')
    plt.xlabel('Number of Occurrences in Browsing History')
    plt.ylabel('Frequency')
    plt.show()

for i in range(8):
    plot_value_counts(codes[i],ads[i])

# %%
# MAKE BOXPLOTS ALL ON ONE PLOT INSTEAD
sns.boxplot(data=all_ads, x='user',y=)

# %%
def plot_top_n_avertiser_frequency(n,code,df):
    # Get the top n most frequent advertisers
    val_counts = df['author_name'].value_counts().head(n)
    
    # Plot the frequency of the top n advertisers
    plt.style.use('ggplot')
    plt.figure(figsize=(10,6))
    sns.barplot(x=val_counts.index, y=val_counts.values)
    plt.title(f'Frequency of Advertiser Accounts for User {code}')
    plt.xlabel('Advertiser Account')
    plt.ylabel('Frequency')
    plt.xticks(rotation=75)
    plt.show()

# %%
for i in range(8):
#     plot_author_frequency(codes[i],ads[i])
    plot_top_n_avertiser_frequency(20,codes[i],ads[i])
# Out:
# /Users/edithpo/miniconda3/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 129419 (\N{BUTTERFLY}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/edithpo/miniconda3/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 127872 (\N{RIBBON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/edithpo/miniconda3/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128133 (\N{NAIL POLISH}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/edithpo/miniconda3/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 127997 (\N{EMOJI MODIFIER FITZPATRICK TYPE-4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### Check for overlap in the advertisers for our users

# %%
# Dictionary for each advertiser and user
advertiser_and_user = {}

# Add the advertisers to dict along with the 
for code, df in zip(codes, ads):
    advertiser_counter = Counter(df['author_name'])
    for key, value in advertiser_counter.items():
        if key in advertiser_and_user:
            advertiser_and_user[key].append((code, value))  # Append both code and count
        else:
            advertiser_and_user[key] = [(code, value)]  # Create a new list

print(advertiser_and_user)
# Out:
# {'annie kartalia': [('50405', 1)], 'coachoutlet': [('50405', 4)], 'Dr. Martens': [('50405', 1), ('33534', 1)], 'natgeowild': [('50405', 1)], 'simmykinns🍒': [('50405', 1), ('12345', 1)], 'ebay': [('50405', 10), ('77217', 1), ('26301', 1), ('33534', 2)], 'Arise': [('50405', 1)], 'Tina Yong': [('50405', 1)], 'Feel Good Foodie': [('50405', 2)], 'Colorescience': [('50405', 1)], 'graysonsmith': [('50405', 1)], 'The Hermidas': [('50405', 2), ('38129', 2)], 'Life of Tanya Marie': [('50405', 3), ('77217', 2), ('26301', 3), ('33534', 1)], 'ColourPop Cosmetics': [('50405', 2)], 'Neto Craves': [('50405', 2)], 'Original Top Ramen': [('50405', 4)], 'Searchlight Pictures': [('50405', 1), ('77217', 1), ('26301', 6), ('33534', 27)], 'LottieLondon': [('50405', 1)], 'Intuit Credit Karma': [('50405', 1)], 'Vinglacé': [('50405', 2)], 'Boar’s Head': [('50405', 1)], 'maggie e | vm2 ☻ 🐾': [('50405', 2)], 'Makeup Revolution': [('50405', 7)], 'charli d’amelio': [('50405', 2)], 'Universal Pictures': [('50405', 3), ('38129', 2), ('33534', 8)], 'Liz Maldonado': [('50405', 3)], "Wendy's": [('50405', 1), ('38129', 1), ('26301', 4), ('33534', 2)], 'Tampax US': [('50405', 4), ('33534', 8)], 'NYX Professional Makeup': [('50405', 5), ('77217', 2), ('26301', 4), ('33534', 1)], 'Wingstop': [('50405', 13), ('77777', 1), ('77217', 2), ('38129', 2), ('26301', 1), ('33534', 1), ('12345', 1)], 'Revolution Skin & Hair': [('50405', 1)], 'skilahblue': [('50405', 1)], 'tacobell': [('50405', 24), ('77217', 8), ('38129', 3), ('26301', 9), ('33534', 15)], 'numbuzin_official': [('50405', 1)], 'sukiwaterhouse': [('50405', 2)], 'indeed': [('50405', 4), ('38129', 1), ('33534', 1), ('12345', 1)], 'Target': [('50405', 6), ('77217', 15), ('38129', 6), ('26301', 7), ('33534', 15), ('12345', 1)], 'christin': [('50405', 1)], 'EverythingJustBaked': [('50405', 2)], 'millie 🌷': [('50405', 1)], 'monse': [('50405', 2)], 'MONOPOLY GO!': [('50405', 3), ('38129', 14), ('33534', 13)], 'themamahedgehog': [('50405', 1)], 'Pantene': [('50405', 2), ('77217', 2), ('38129', 1), ('26301', 4)], 'Pop-Tarts': [('50405', 4), ('77217', 4), ('38129', 1), ('26301', 3), ('33534', 1), ('12345', 1)], 'FIGS': [('50405', 3), ('38129', 2), ('26301', 2)], 'discoverofficial': [('50405', 11), ('38129', 3), ('26301', 6), ('33534', 4)], 'coachella': [('50405', 1), ('26301', 1), ('33534', 1)], 'marshalls': [('50405', 16), ('77217', 12), ('38129', 6), ('26301', 10), ('33534', 12)], 'hismile': [('50405', 5), ('33534', 2), ('12345', 1)], 'Justin Eseller': [('50405', 1)], 'KFC': [('50405', 4)], 'myspace\u20022.0': [('50405', 2), ('26301', 1)], 'nyxcosmetics': [('50405', 9), ('77217', 28), ('38129', 3), ('26301', 9)], 'jacimariesmith': [('50405', 3), ('77217', 1)], 'firstaidbeauty': [('50405', 26), ('26301', 1)], 'zoekimkenealy': [('50405', 2), ('38129', 1), ('26301', 1)], 'Koia': [('50405', 1)], 'dreamrecovery': [('50405', 1)], 'Jamie — Registered Dietitian': [('50405', 5)], 'thegeneralauto': [('50405', 3), ('26301', 1)], 'Zillennial Finance Expert': [('50405', 1), ('26301', 1)], 'suzie!': [('50405', 1), ('26301', 1), ('33534', 1)], 'tjmaxx': [('50405', 10), ('77777', 1), ('77217', 5), ('38129', 13), ('26301', 10), ('33534', 5)], "REESE'S": [('50405', 11), ('77217', 4), ('38129', 5), ('26301', 15), ('33534', 3), ('12345', 1)], 'Subway®': [('50405', 13), ('77777', 1), ('33534', 12), ('12345', 1)], 'Angelica Corona': [('50405', 1), ('26301', 1)], 'Madison Rae \U0001faa9': [('50405', 4)], 'MEL': [('50405', 1)], 'DaniellePheloung': [('50405', 1)], 'Secret': [('50405', 4), ('38129', 1), ('26301', 4), ('33534', 7)], 'elfyeah': [('50405', 9)], 'Danni Juhl 🎬': [('50405', 1), ('33534', 1)], 'Anthropologie Weddings': [('50405', 4), ('26301', 1)], 'Daniela Araujo': [('50405', 1)], 'Cords Club': [('50405', 2)], 'Megan Homme': [('50405', 7)], 'LaRochePosayUS': [('50405', 3)], 'Amber': [('50405', 1)], 'kanz sulaiman': [('50405', 1)], 'therealsourpatchkids': [('50405', 5), ('77217', 18), ('38129', 6), ('26301', 1), ('12345', 1)], 'primev ...

# %%
num_overlap_advertisers = 0
for advertiser, user_list in advertiser_and_user.items():
    if len(user_list) > 2:
        num_overlap_advertisers += 1
        print(advertiser)
        print(user_list)
        print()
print(num_overlap_advertisers)
# Out:
# ebay
# [('50405', 10), ('77217', 1), ('26301', 1), ('33534', 2)]
#
# Life of Tanya Marie
# [('50405', 3), ('77217', 2), ('26301', 3), ('33534', 1)]
#
# Searchlight Pictures
# [('50405', 1), ('77217', 1), ('26301', 6), ('33534', 27)]
#
# Universal Pictures
# [('50405', 3), ('38129', 2), ('33534', 8)]
#
# Wendy's
# [('50405', 1), ('38129', 1), ('26301', 4), ('33534', 2)]
#
# NYX Professional Makeup
# [('50405', 5), ('77217', 2), ('26301', 4), ('33534', 1)]
#
# Wingstop
# [('50405', 13), ('77777', 1), ('77217', 2), ('38129', 2), ('26301', 1), ('33534', 1), ('12345', 1)]
#
# tacobell
# [('50405', 24), ('77217', 8), ('38129', 3), ('26301', 9), ('33534', 15)]
#
# indeed
# [('50405', 4), ('38129', 1), ('33534', 1), ('12345', 1)]
#
# Target
# [('50405', 6), ('77217', 15), ('38129', 6), ('26301', 7), ('33534', 15), ('12345', 1)]
#
# MONOPOLY GO!
# [('50405', 3), ('38129', 14), ('33534', 13)]
#
# Pantene
# [('50405', 2), ('77217', 2), ('38129', 1), ('26301', 4)]
#
# Pop-Tarts
# [('50405', 4), ('77217', 4), ('38129', 1), ('26301', 3), ('33534', 1), ('12345', 1)]
#
# FIGS
# [('50405', 3), ('38129', 2), ('26301', 2)]
#
# discoverofficial
# [('50405', 11), ('38129', 3), ('26301', 6), ('33534', 4)]
#
# coachella
# [('50405', 1), ('26301', 1), ('33534', 1)]
#
# marshalls
# [('50405', 16), ('77217', 12), ('38129', 6), ('26301', 10), ('33534', 12)]
#
# hismile
# [('50405', 5), ('33534', 2), ('12345', 1)]
#
# nyxcosmetics
# [('50405', 9), ('77217', 28), ('38129', 3), ('26301', 9)]
#
# zoekimkenealy
# [('50405', 2), ('38129', 1), ('26301', 1)]
#
# suzie!
# [('50405', 1), ('26301', 1), ('33534', 1)]
#
# tjmaxx
# [('50405', 10), ('77777', 1), ('77217', 5), ('38129', 13), ('26301', 10), ('33534', 5)]
#
# REESE'S
# [('50405', 11), ('77217', 4), ('38129', 5), ('26301', 15), ('33534', 3), ('12345', 1)]
#
# Subway®
# [('50405', 13), ('77777', 1), ('33534', 12), ('12345', 1)]
#
# Secret
# [('50405', 4), ('38129', 1), ('26301', 4), ('33534', 7)]
#
# therealsourpatchkids
# [('50405', 5), ('77217', 18), ('38129', 6), ('26301', 1), ('12345', 1)]
#
# primevideo
# [('50405', 5), ('77217', 7), ('38129', 8), ('26301', 6), ('33534', 11)]
#
# ChanelOfficial
# [('50405', 3), ('38129', 4), ('26301', 2)]
#
# Maybelline New York
# [('50405', 13), ('77217', 10), ('26301', 13), ('33534', 4), ('12345', 1)]
#
# GoldBondUS
# [('50405', 2), ('77217', 2), ('38129', 1), ('26301', 1), ('33534', 12)]
#
# Kohl’s
# [('50405', 2), ('77217', 1), ('38129', 1), ('26301', 1)]
#
# ruggable
# [('50405', 6), ('77217', 1), ('26301', 2)]
#
# Dove
# [('50405', 6), ('77217', 7), ('38129', 18), ('26301', 10), ('33534', 3)]
#
# hiddenvalleyranch
# [('50405', 4), ('77217', 3), ('38129', 3), ('26301', 2)]
#
# Crumbl Cookies
# [('50405', 23), ('77217', 2), ('26301', 2)]
#
# BVLGARI
# [('50405', 1), ('77217', 1), ('38129', 2), ('33534', 1), ('12345', 1)]
#
# Chewy
# [('50405', 9), ('77217', 7), ('38129', 32), ('26301', 7), ('33534', 3), ('12345', 2)]
#
# Walmart
# [('50405', 8), ('77217', 14), ('38129', 5), ('26301', 20), ('33534', 2), ('12345', 2)]
#
# Nature Made
# [('50405', 5), ('38129', 3), ('33534', 5)]
#
# lemon8unitedstates
# [('50405', 10), ('77217', 6), ('26301', 4)]
#
# TikTok Research
# [('50405', 17), ('77217', 5), ('38129', 2), ('26301', 5), ('33534', 6)]
#
# sephora
# [('50405', 14), ('77777', 4), ('77217', 10), ('38129', 1), ('26301', 1), ('33534', 13), ('12345', 1)]
#
# Dominos
# [('50405', 4), ('38129', 4), ('33534', 8)]
#
# britscookin
# [('50405', 2), ('77217', 1), ('26301', 2)]
#
# Ulta Beauty
# [('50405', 7), ('77217', 16), ('38129', 2), ('26301', 4), ('33534', 3)]
#
# Peacock
# [('50405', 9), ('77777', 1), ('77217', 5), ('38129', 11), ('26301', 8), ('33534', 6)]
#
# Folgers
# [('50405', 2), ('38129', 2), ('26301', 1)]
#
# Autotrader
# [('50405', 4), ('38129', 2), ('26301', 2)]
#
# Screen for Type 1
# [('50405', 2), ('38129', 1), ('33534', 10)]
#
# Alka-Seltzer
# [('50405', 2), ('77777', 1), ('77217', 1), ('26301', 1)]
#
# Prada Beauty
# [('50405', 8), ('77217', 1), ('38129', 2), ('12345', 1)]
#
# hillspet
# [('50405', 1), ('38129', 5), ('26301', 2)]
#
# DermDoctor | Dr. Shah
# [('50405', 1), ('26301', 5), ('33534', 2)]
#
# command
# [('50405', 1), ('38129', 1), ('26301', 1), ('12345', 1)]
#
# Zachary Reality
# [('50405', 1), ('38129', 1), ('26301', 1), ('33534', 1)]
#
# snickers
# [('50405', 1), ('38129', 4), ('26301', 2)]
#
# Heinz_US
# [('50405', 1), ('38129', 1), ('26301', 1), ('33534', 1)]
#
# mrsmeyerscleanday
# [('50405', 2), ('77217', 6), ('38129', 1), ('26301', 2), ('12345', 1)]
#
# paramountplus
# [('50405', 2), ('77217', 3), ('38129', 3)]
#
# Amazon Prime
# [('50405', 2), ('77217', 4), ('26301', 6)]
#
# Sephora
# [('50405', 4), ('77217', 37), ('38129', 1), ('26301', 3), ('33534', 3), ('12345', 2)]
#
# laneige_us
# [('50405', 1), ('38129', 2), ('33534', 1)]
#
# Red Bull
# [('50405', 4), ('77217', 2), ('38129', 3)]
#
# CIBINQO_abrocitinib
# [('50405', 6), ('77217', 2), ('26301', 2), ('33534', 7)]
#
# Tinder: Dating, Chat & Friends
# [('50405', 3), ('77217', 7), ('38129', 1), ('26301', 5)]
#
# asos
# [('50405', 1), ('77217', 1), ('33534', 1), ('12345', 1)]
#
# princesspolly
# [('50405', 3), ('77217', 3), ('38129', 1), ('26301', 1)]
#
# ohpolly
# [('50405', 5), ('38129', 1), ('26301', 3)]
#
# MOTELROCKS
# [('50405', 1), ('38129', 1), ('33534', 1)]
#
# Introducing Meta Quest 3
# [('50405', 9), ('77777', 1), ('77217', 5), ('26301', 2), ('33534', 3), ('12345', 2)]
#
# Plan B One-Step
# [('50405', 2), ('77217', 4), ('26301', 2), ('33534', 5)]
#
# Allstate
# [('50405', 17), ('77217', 8), ('38129', 4), ('26301', 3), ('33534', 3)]
#
# drinkcirkul
# [('50405', 6), ('77777', 1), ('77217', 10), ('38129', 4), ('26301', 4), ('33534', 5)]
#
# AT&T
# [('50405', 9), ('77217', 5), ('12345', 1)]
#
# Chipotle
# [('50405', 2), ('26301', 5), ('33534', 4), ('12345', 2)]
#
# Beti - Makeupsessions
# [('50405', 2), ('26301', 1), ('33534', 1)]
#
# Freeform
# [('50405', 3), ('26301', 1), ('33534', 4)]
#
# Dunkin'
# [('50405', 3), ('38129', 3), ('26301', 1), ('33534', 2)]
#
# peacock
# [('50405', 9), ('77217', 7), ('26301', 2), ('12345', 1)]
#
# Ralph Lauren
# [('50405', 2), ('77217', 3), ('33534', 2)]
#
# Meet the new Meta Quest 3
# [('50405', 2), ('26301', 1), ('33534', 1)]
#
# HillshireFarm
# [('50405', 4), ('38129', 3), ('26301', 8)]
#
# Energizer
# [('50405', 4), ('77217', 8), ('38129', 1)]
#
# Visa
# [('50405', 1), ('38129', 2), ('33534', 1)]
#
# pureleaf
# [('50405', 1), ('38129', 3), ('26301', 1)]
#
# KIT KAT ®️
# [('50405', 2), ('77217', 3), ('38129', 2), ('26301', 3), ('33534', 1), ('12345', 1)]
#
# T-Mobile
# [('50405', 9), ('77217', 1), ('33534', 3)]
#
# aprilbasi | chemist
# [('50405', 3), ('26301', 3), ('33534', 2)]
#
# Rocket Money - Bills & Budgets
# [('50405', 7), ('77217', 1), ('33534', 1)]
#
# TurboTax
# [('50405', 3), ('26301', 3), ('33534', 11)]
#
# paulaschoice
# [('50405', 12), ('77217', 2), ('26301', 2), ('33534', 1)]
#
# McDonalds
# [('50405', 6), ('26301', 12), ('33534', 2)]
#
# HERSHEY'S
# [('50405', 3), ('77777', 1), ('77217', 1), ('38129', 1), ('26301', 3), ('33534', 3)]
#
# Amazon Home
# [('50405', 9), ('77777', 2), ('77217', 47), ('38129', 2), ('26301', 4)]
#
# Bumble
# [('50405', 8), ('77217', 4), ('38129', 1), ('33534', 3)]
#
# PlayStation
# [('50405', 2), ('77217', 1), ('33534', 5)]
#
# Panera Bread
# [('50405', 9), ('77217', 1), ('38129', 1), ('26301', 3), ('33534', 13)]
#
# focusfeatures
# [('50405', 2), ('38129', 6), ('33534', 12)]
#
# Steffy Degreff
# [('50405', 1), ('26301', 1), ('33534', 1)]
#
# Coach
# [('50405', 2), ('77217', 1), ('26301', 1), ('33534', 1)]
#
# Starry
# [('50405', 7), ('77217', 4), ('38129', 1), ('26301', 4)]
#
# HALLS
# [('50405', 2), ('77217', 6), ('12345', 1)]
#
# Adore Me
# [('50405', 4), ('77217', 1), ('38129', 8), ('26301', 1), ('33534', 4)]
#
# IHOP
# [('50405', 8), ('77217', 6), ('38129', 1)]
#
# PizzaHut
# [('50405', 7), ('77217', 3), ('38129', 2), ('26301', 1), ('33534', 1)]
#
# TheOfficialPandora
# [('50405', 2), ('38129', 1), ('26301', 3)]
#
# DisneyPlus
# [('50405', 6), ('38129', 9), ('26301', 2)]
#
# NexplanonUS
# [('50405', 8), ('77217', 11), ('38129', 1), ('26301', 5)]
#
# Pampers
# [('50405', 3), ('77217', 2), ('38129', 1), ('26301', 8), ('33534', 3)]
#
# Nutrish
# [('50405', 1), ('38129', 1), ('26301', 2)]
#
# SHAKE SHACK
# [('50405', 3), ('77217', 1), ('26301', 1), ('33534', 2)]
#
# BEHR Paint
# [('50405', 8), ('38129', 1), ('26301', 2)]
#
# Keurig
# [('50405', 4), ('26301', 2), ('33534', 1)]
#
# BurgerKing
# [('50405', 4), ('77217', 7), ('38129', 2), ('26301', 5), ('33534', 3)]
#
# papajohns
# [('50405', 7), ('38129', 4), ('33534', 1)]
#
# Canada Goose
# [('50405', 2), ('38129', 2), ('26301', 1)]
#
# OREO Cookie
# [('50405', 7), ('77777', 2), ('77217', 14), ('38129', 1), ('26301', 1), ('33534', 3), ('12345', 1)]
#
# leleda
# [('50405', 1), ('26301', 1), ('33534', 1)]
#
# TikTok
# [('50405', 27), ('77777', 1), ('77217', 13), ('38129', 1), ('33534', 11), ('12345', 1)]
#
# SubaruOfAmerica
# [('50405', 2), ('77217', 1), ('33534', 2), ('12345', 1)]
#
# Dell
# [('50405', 3), ('77217', 1), ('12345', 1)]
#
# Milk-Bone
# [('50405', 1), ('77217', 1), ('38129', 2), ('26301', 1), ('12345', 1)]
#
# Photoshop
# [('50405', 1), ('77217', 2), ('33534', 3)]
#
# Tatyana
# [('50405', 1), ('26301', 1), ('33534', 2)]
#
# CapitalOne
# [('50405', 11), ('77217', 3), ('38129', 4), ('26301', 5), ('33534', 1), ('12345', 2)]
#
# Starbucks
# [('50405', 8), ('26301', 14), ('33534', 9)]
#
# JBL Audio
# [('50405', 4), ('77777', 1), ('77217', 2), ('12345', 1)]
#
# PopCorners
# [('50405', 2), ('33534', 10), ('12345', 2)]
#
# metaquest
# [('50405', 2), ('26301', 1), ('33534', 1)]
#
# Kate Steinberg
# [('50405', 1), ('26301', 1), ('33534', 1)]
#
# glad
# [('50405', 2), ('38129', 2), ('26301', 2), ('12345', 1)]
#
# Coca-Cola
# [('50405', 7), ('77777', 1), ('77217', 9), ('26301', 3), ('33534', 7), ('12345', 1)]
#
# Miki Rai
# [('50405', 2), ('77777', 1), ('33534', 1)]
#
# MountainDew
# [('50405', 2), ('77777', 1), ('77217', 9), ('38129', 2), ('33534', 4), ('12345', 1)]
#
# rabanne
# [('50405', 6), ('77217', 22), ('38129', 1)]
#
# Pepsi
# [('50405', 6), ('77217', 1), ('38129', 2), ('33534', 8)]
#
# Mercedes-Benz USA
# [('50405', 1), ('38129', 1), ('26301', 1)]
#
# HaloTop
# [('50405', 3), ('77777', 1), ('38129', 1), ('26301', 1)]
#
# nespresso
# [('50405', 4), ('77217', 1), ('38129', 3), ('26301', 4), ('33534', 3), ('12345', 1)]
#
# timhortons
# [('50405', 2), ('26301', 1), ('33534', 1)]
#
# Courtney Sarracino
# [('50405', 1), ('26301', 3), ('33534', 1)]
#
# Olay
# [('50405', 9), ('77217', 12), ('38129', 3), ('26301', 3), ('33534', 6), ('12345', 1)]
#
# Sierra
# [('50405', 4), ('77217', 3), ('12345', 1)]
#
# Adobe
# [('50405', 2), ('77217', 1), ('38129', 1)]
#
# Meow Mix
# [('50405', 1), ('77217', 2), ('38129', 1), ('26301', 1), ('12345', 1)]
#
# disneyplus
# [('50405', 4), ('77217', 7), ('26301', 1), ('33534', 2), ('12345', 1)]
#
# tiffanyandco
# [('50405', 3), ('77217', 6), ('38129', 1), ('33534', 1), ('12345', 1)]
#
# OPI
# [('50405', 1), ('77777', 1), ('38129', 10), ('26301', 6), ('12345', 1)]
#
# Burt's Bees
# [('50405', 2), ('77777', 2), ('77217', 2), ('33534', 2)]
#
# Tinder
# [('50405', 1), ('77217', 5), ('26301', 1)]
#
# Amazon Shopping
# [('50405', 9), ('77217', 137), ('38129', 11), ('26301', 21), ('33534', 2)]
#
# clinique
# [('50405', 11), ('77217', 9), ('38129', 1), ('26301', 3)]
#
# WFPUSA
# [('50405', 2), ('38129', 2), ('26301', 2), ('33534', 4)]
#
# Max
# [('50405', 3), ('77217', 1), ('26301', 3), ('33534', 17)]
#
# Amazon
# [('50405', 3), ('77217', 75), ('38129', 19), ('26301', 5)]
#
# Scrubbing Bubbles
# [('50405', 1), ('77217', 1), ('12345', 2)]
#
# Domino’s
# [('50405', 3), ('77217', 3), ('38129', 1), ('26301', 4), ('33534', 3)]
#
# Too Faced
# [('50405', 1), ('38129', 5), ('26301', 7)]
#
# Prada
# [('50405', 1), ('77217', 3), ('38129', 3), ('26301', 2), ('12345', 1)]
#
# theritzcrackersofficial
# [('50405', 1), ('77217', 1), ('26301', 3), ('12345', 2)]
#
# StaplesStores
# [('50405', 2), ('26301', 1), ('33534', 3), ('12345', 1)]
#
# netflix
# [('50405', 1), ('38129', 3), ('26301', 1), ('33534', 3)]
#
# DiscoverOfficial
# [('50405', 1), ('77217', 1), ('12345', 1)]
#
# CVS Pharmacy
# [('50405', 1), ('77217', 7), ('38129', 2), ('33534', 1)]
#
# ashley noelle
# [('50405', 2), ('77777', 1), ('26301', 1), ('33534', 1)]
#
# Danielle Athena
# [('50405', 1), ('26301', 1), ('33534', 1)]
#
# Valentino Beauty
# [('50405', 3), ('77217', 15), ('38129', 2)]
#
# LUMIFY Eyes
# [('50405', 1), ('77217', 2), ('12345', 1)]
#
# TWIX
# [('50405', 2), ('77217', 1), ('33534', 2)]
#
# Extra
# [('50405', 2), ('77217', 2), ('33534', 2)]
#
# 5Gum
# [('50405', 3), ('77217', 2), ('33534', 3)]
#
# Viktor&Rolf Fragrances
# [('50405', 2), ('38129', 2), ('26301', 1)]
#
# aerie
# [('50405', 6), ('77217', 4), ('38129', 5), ('26301', 4)]
#
# Dave - Banking for humans
# [('50405', 2), ('77217', 1), ('38129', 1)]
#
# Gatorade
# [('50405', 2), ('38129', 1), ('26301', 1)]
#
# ChipsAhoy!
# [('50405', 2), ('77777', 1), ('77217', 3), ('33534', 3)]
#
# hydroflask
# [('50405', 10), ('77217', 3), ('38129', 3), ('26301', 2)]
#
# NewEnglandHondaDealers
# [('50405', 3), ('77777', 1), ('77217', 3), ('38129', 1), ('26301', 5), ('33534', 4), ('12345', 1)]
#
# Sally Beauty
# [('50405', 1), ('77217', 5), ('12345', 1)]
#
# Rockstar Games
# [('50405', 1), ('26301', 1), ('33534', 1)]
#
# International_Delight
# [('50405', 2), ('77777', 1), ('77217', 1), ('38129', 1), ('26301', 4), ('33534', 1), ('12345', 1)]
#
# Lemon8 - Lifestyle Community
# [('50405', 1), ('77777', 1), ('77217', 1)]
#
# Rockstar Energy
# [('50405', 4), ('77777', 1), ('77217', 5), ('38129', 2), ('33534', 1)]
#
# BitLife - Life Simulator
# [('50405', 1), ('77217', 1), ('38129', 2), ('33534', 1)]
#
# sprite
# [('50405', 2), ('77777', 1), ('77217', 2), ('33534', 1)]
#
# Victoria's Secret
# [('50405', 1), ('38129', 2), ('26301', 3), ('12345', 1)]
#
# DoorDash
# [('50405', 3), ('77217', 6), ('33534', 1), ('12345', 2)]
#
# göt2b® glued
# [('50405', 2), ('77217', 2), ('26301', 1), ('12345', 2)]
#
# mmschocolate
# [('50405', 2), ('38129', 1), ('26301', 1)]
#
# PepsiAtWalmart
# [('50405', 1), ('77777', 1), ('12345', 2)]
#
# Fancy Feast
# [('50405', 2), ('77777', 2), ('77217', 2), ('38129', 1), ('33534', 5)]
#
# Tao
# [('50405', 1), ('77777', 1), ('38129', 2), ('26301', 1), ('12345', 1)]
#
# Ray-Ban Meta
# [('50405', 3), ('77777', 2), ('77217', 6), ('33534', 11), ('12345', 2)]
#
# Palmer's
# [('50405', 1), ('77217', 3), ('38129', 4), ('26301', 2), ('12345', 2)]
#
# windsorstore
# [('50405', 1), ('38129', 1), ('26301', 1), ('12345', 1)]
#
# Cheetos
# [('50405', 1), ('33534', 2), ('12345', 1)]
#
# cetaphilus
# [('50405', 1), ('26301', 1), ('12345', 1)]
#
# Chime - Mobile Banking
# [('50405', 1), ('38129', 1), ('26301', 2)]
#
# Frito Lay Minis Canisters
# [('50405', 2), ('77777', 1), ('77217', 2), ('33534', 2), ('12345', 2)]
#
# Hey Sam
# [('50405', 3), ('77217', 1), ('26301', 6), ('33534', 4)]
#
# Charmin
# [('50405', 1), ('38129', 1), ('26301', 1)]
#
# colgate_us
# [('50405', 1), ('38129', 2), ('26301', 1)]
#
# YETI
# [('50405', 2), ('77217', 3), ('12345', 1)]
#
# Cheez-It
# [('50405', 1), ('77777', 1), ('77217', 1), ('38129', 1), ('33534', 1), ('12345', 1)]
#
# esteelauder
# [('50405', 2), ('77217', 12), ('26301', 1), ('12345', 1)]
#
# JOANN Stores
# [('50405', 1), ('38129', 1), ('33534', 1), ('12345', 2)]
#
# MinuteClinic
# [('50405', 1), ('77217', 1), ('38129', 1), ('26301', 1), ('12345', 1)]
#
# Lindt
# [('50405', 1), ('77217', 1), ('12345', 1)]
#
# treehutusa
# [('50405', 2), ('77217', 5), ('12345', 2)]
#
# Citizens
# [('50405', 8), ('77777', 1), ('77217', 15), ('38129', 5), ('26301', 9), ('33534', 15)]
#
# Athleta
# [('50405', 2), ('77217', 5), ('12345', 2)]
#
# Victoria
# [('50405', 2), ('33534', 1), ('12345', 1)]
#
# ophelia 🦋
# [('50405', 2), ('77217', 1), ('33534', 2)]
#
# Yoatzi
# [('50405', 1), ('26301', 4), ('33534', 2)]
#
# carolinaherreraofficial
# [('50405', 1), ('77217', 7), ('38129', 1)]
#
# Cartier
# [('50405', 1), ('38129', 1), ('33534', 1)]
#
# Nike: Shop Shoes & Clothes
# [('50405', 1), ('77777', 1), ('77217', 3), ('33534', 4)]
#
# tazo
# [('50405', 1), ('33534', 1), ('12345', 1)]
#
# Kelly Strack
# [('50405', 1), ('26301', 1), ('33534', 1)]
#
# MassBay Community College
# [('50405', 1), ('38129', 1), ('26301', 2), ('33534', 1)]
#
# givenchybeauty
# [('50405', 1), ('77777', 1), ('77217', 5), ('38129', 1), ('33534', 1), ('12345', 2)]
#
# Porsche
# [('50405', 1), ('77217', 3), ('33534', 3), ('12345', 1)]
#
# methodproducts
# [('50405', 1), ('38129', 3), ('26301', 3), ('33534', 3)]
#
# Ben's Original
# [('50405', 2), ('77217', 1), ('38129', 1), ('26301', 1), ('33534', 4)]
#
# pfizerinc
# [('50405', 3), ('77217', 6), ('33534', 3)]
#
# publiclandsshop
# [('50405', 9), ('77217', 9), ('26301', 4), ('33534', 4)]
#
# Google Pixel
# [('50405', 2), ('77217', 12), ('33534', 11)]
#
# Homesense
# [('50405', 3), ('77217', 12), ('33534', 4)]
#
# Erin O’Brien
# [('50405', 1), ('33534', 3), ('12345', 1)]
#
# Madeline Salazar
# [('50405', 1), ('77217', 2), ('33534', 1)]
#
# Dasher
# [('50405', 5), ('77217', 1), ('33534', 16), ('12345', 1)]
#
# Dr Dray | Dermatologist
# [('50405', 1), ('77217', 1), ('38129', 2), ('26301', 1)]
#
# DoorDash - Driver
# [('50405', 5), ('77777', 1), ('77217', 3)]
#
# Gymshark
# [('50405', 5), ('77217', 1), ('12345', 1)]
#
# Shop with Google
# [('50405', 2), ('77777', 4), ('77217', 34)]
#
# H&M
# [('50405', 2), ('77217', 4), ('38129', 1), ('26301', 4)]
#
# MilanLaserHairRemoval
# [('50405', 1), ('33534', 1), ('12345', 1)]
#
# smartwater
# [('50405', 3), ('77217', 2), ('38129', 1)]
#
# Dolls Kill
# [('50405', 2), ('77217', 3), ('38129', 1), ('33534', 6)]
#
# Billie
# [('50405', 1), ('26301', 1), ('33534', 1)]
#
# Curology
# [('50405', 4), ('38129', 1), ('12345', 1)]
#
# Savage X Fenty
# [('50405', 2), ('77217', 2), ('38129', 4), ('12345', 1)]
#
# The Bachelor
# [('50405', 2), ('38129', 1), ('26301', 3), ('33534', 2)]
#
# Jolly Rancher
# [('50405', 3), ('38129', 2), ('26301', 2)]
#
# SONIC Drive-In
# [('50405', 9), ('77217', 1), ('38129', 6), ('26301', 1)]
#
# Doritos
# [('50405', 1), ('38129', 2), ('12345', 1)]
#
# AquaphorUS
# [('50405', 5), ('77777', 1), ('33534', 1)]
#
# arcsmile
# [('50405', 3), ('26301', 1), ('12345', 1)]
#
# lovemysilk
# [('50405', 5), ('77217', 4), ('26301', 1)]
#
# FX Networks
# [('50405', 2), ('77217', 1), ('38129', 7), ('33534', 2)]
#
# thenorthface
# [('50405', 1), ('77217', 2), ('12345', 1)]
#
# Lulus
# [('50405', 1), ('77217', 2), ('38129', 3)]
#
# Prime Video
# [('50405', 1), ('77217', 1), ('38129', 8), ('26301', 2), ('33534', 4), ('12345', 1)]
#
# Dr Pepper
# [('50405', 3), ('38129', 1), ('33534', 14)]
#
# Emily Sanchez
# [('50405', 2), ('26301', 1), ('33534', 1)]
#
# hulu
# [('50405', 1), ('77217', 3), ('38129', 1), ('33534', 3)]
#
# neutrogena_us
# [('50405', 1), ('38129', 4), ('26301', 2)]
#
# Soraya Raji
# [('50405', 2), ('26301', 3), ('33534', 1)]
#
# P&G at Walmart
# [('50405', 1), ('77217', 1), ('38129', 2)]
#
# Project Makeover
# [('50405', 1), ('77217', 1), ('38129', 1)]
#
# Booking.com
# [('50405', 5), ('77217', 10), ('26301', 1)]
#
# Xfinity
# [('50405', 4), ('77217', 2), ('38129', 6)]
#
# Popeyes®
# [('50405', 1), ('38129', 1), ('26301', 2)]
#
# Impulse - Brain Training
# [('50405', 1), ('77217', 1), ('38129', 1)]
#
# aelfricedenofficial
# [('50405', 1), ('77217', 1), ('38129', 2)]
#
# forloveandlemons
# [('50405', 1), ('38129', 1), ('26301', 1)]
#
# Liquid I.V.
# [('50405', 1), ('38129', 1), ('26301', 2)]
#
# Visa US
# [('77777', 1), ('38129', 2), ('26301', 2), ('33534', 1), ('12345', 1)]
#
# SalonCentric
# [('77777', 1), ('33534', 1), ('12345', 1)]
#
# ALTOIDS
# [('77777', 1), ('77217', 2), ('33534', 1)]
#
# STARZ
# [('77777', 1), ('77217', 1), ('38129', 1), ('26301', 1), ('12345', 2)]
#
# Rothy's
# [('77217', 3), ('38129', 1), ('26301', 1)]
#
# Trolli
# [('77217', 3), ('33534', 3), ('12345', 1)]
#
# Abercrombie
# [('77217', 2), ('26301', 3), ('33534', 1)]
#
# GarnierUSA
# [('77217', 3), ('38129', 2), ('26301', 3)]
#
# Disney+
# [('77217', 1), ('26301', 3), ('33534', 1)]
#
# hal pal⁉️
# [('77217', 1), ('26301', 2), ('33534', 1)]
#
# Nerds
# [('77217', 6), ('38129', 1), ('26301', 2)]
#
# American Eagle
# [('77217', 2), ('38129', 5), ('26301', 5), ('33534', 1)]
#
# Spotify
# [('77217', 3), ('38129', 3), ('33534', 1)]
#
# Takis
# [('77217', 1), ('38129', 2), ('26301', 2)]
#
# Miu Miu
# [('77217', 2), ('38129', 1), ('26301', 1)]
#
# AnnTaylor
# [('77217', 1), ('26301', 1), ('12345', 1)]
#
# Brianna Joye Kohn ✨
# [('77217', 1), ('26301', 1), ('33534', 2)]
#
# Michaels Stores
# [('77217', 9), ('38129', 1), ('26301', 1), ('12345', 1)]
#
# Allure
# [('77217', 1), ('38129', 3), ('12345', 2)]
#
# Jared Jewelers
# [('77217', 1), ('26301', 2), ('33534', 1), ('12345', 1)]
#
# UPS
# [('77217', 1), ('38129', 3), ('26301', 1), ('12345', 1)]
#
# officialpandaexpress
# [('77217', 3), ('38129', 1), ('12345', 1)]
#
# Dr.Jart+ US
# [('77217', 4), ('38129', 3), ('26301', 1)]
#
# HeySam
# [('77217', 1), ('38129', 3), ('33534', 4)]
#
# #StandUpToJewishHate
# [('38129', 3), ('26301', 3), ('33534', 2)]
#
# Max Mara
# [('38129', 4), ('26301', 3), ('12345', 1)]
#
# Burt’s Bees
# [('38129', 3), ('26301', 3), ('33534', 2)]
#
# Lyft
# [('38129', 4), ('26301', 1), ('33534', 1)]
#
# MarcJacobs
# [('38129', 1), ('26301', 2), ('12345', 2)]
#
# DuneMovie
# [('38129', 7), ('26301', 1), ('33534', 4)]
#
# skittles
# [('38129', 2), ('26301', 5), ('33534', 1)]
#
# JergensUS
# [('38129', 1), ('26301', 2), ('12345', 1)]
#
# Bose
# [('38129', 3), ('26301', 1), ('33534', 1)]
#
# LASIK.com
# [('38129', 3), ('26301', 3), ('33534', 1)]
#
# McDonald's
# [('38129', 5), ('26301', 12), ('33534', 18)]
#
# MeUndies
# [('38129', 1), ('26301', 1), ('33534', 2)]
#
# candlelight.concerts
# [('38129', 2), ('26301', 3), ('33534', 7)]
#
# CeraVe
# [('38129', 2), ('26301', 3), ('33534', 9)]
#
# Netflix
# [('38129', 1), ('26301', 1), ('33534', 3)]
#
# Tivona
# [('38129', 1), ('26301', 1), ('33534', 1)]
#
# Big Y Foods
# [('26301', 3), ('33534', 2), ('12345', 1)]
#
# 308

# %%
# Look at the time range for each user, monthly
# maybe make a couple of groups for each holiday
